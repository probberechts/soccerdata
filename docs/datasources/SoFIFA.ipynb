# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# %env SOCCERDATA_LOGLEVEL=ERROR
# %env SOCCERDATA_NOCACHE=True
# %env SOCCERDATA_NOSTORE=True
# Out:
# env: SOCCERDATA_LOGLEVEL=ERROR
# env: SOCCERDATA_NOCACHE=True
# env: SOCCERDATA_NOSTORE=True

# %%
import soccerdata as sd

# %% [markdown]
# # SoFIFA

# %%
sofifa = sd.SoFIFA(leagues="ENG-Premier League", seasons=2021)
print(sofifa.__doc__)
# Out:
# /cw/dtaijupiter/NoCsBack/dtai/pieterr/Projects/soccerdata/soccerdata/_common.py:246: UserWarning: Season id "2021" is ambiguous: interpreting as "20-21"
#   warnings.warn(msg)
# Provides pd.DataFrames from data at http://sofifa.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/SoFIFA``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include.
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     use_tor : bool
#         Whether to use the Tor network to hide your IP.
#     no_cache : bool
#         If True, will not use cached data.
#     no_store : bool
#         If True, will not store downloaded data.
#     data_dir : Path
#         Path to directory where data will be cached.

# %% [markdown]
# ## EA Sports FIFA player ratings

# %%
ratings = sofifa.read_ratings()
ratings.head()
# Out:
#                                 league season       overall_rating potential  \
# player_name
# Aaron Cresswell     ENG-Premier League   2021  Best Overall Rating      None
# Aaron Ramsdale      ENG-Premier League   2021  Best Overall Rating      None
# Abdoulaye Doucouré  ENG-Premier League   2021  Best Overall Rating      None
# Adam Lallana        ENG-Premier League   2021  Best Overall Rating      None
# Adam Webster        ENG-Premier League   2021  Best Overall Rating      None
#
#                    crossing finishing heading_accuracy short_passing volleys  \
# player_name
# Aaron Cresswell          83        54               68            77      48
# Aaron Ramsdale           15        14               15            54      16
# Abdoulaye Doucouré       69        75               69            81      68
# Adam Lallana             74        69               64            80      72
# Adam Webster             50        30               76            74      27
#
#                    dribbling curve fk_accuracy long_passing ball_control  \
# player_name
# Aaron Cresswell           76    80          73           69           77
# Aaron Ramsdale            18    17          16           54           35
# Abdoulaye Doucouré        79    44          42           77           81
# Adam Lallana              77    77          66           75           80
# Adam Webster              68    27          25           70           73
#
#                    acceleration sprint_speed agility reactions balance  \
# player_name
# Aaron Cresswell              72           67      73        78      81
# Aaron Ramsdale               47           50      53        80      49
# Abdoulaye Doucouré           67           76      65        79      72
# Adam Lallana                 70           64      77        73      75
# Adam Webster                 64           74      63        74      57
#
#                    shot_power jumping stamina strength long_shots aggression  \
# player_name
# Aaron Cresswell            71      86      74       61         66         73
# Aaron Ramsdale             63      66      35       59         15         35
# Abdoulaye Doucouré         84      73      90       82         77         78
# Adam Lallana               72      68      48       60         68         71
# Adam Webster               37      77      69       77         32         75
#
#                    interceptions positioning vision penalties composure  \
# player_name
# Aaron Cresswell               77          60     68        59        72
# Aaron Ramsdale                24          18     64        25        65
# Abdoulaye Doucouré            81          77     75        54        77
# Adam Lallana                  63          72     80        70        80
# Adam Webster                  76          26     53        24        77
#
#                    marking standing_tackle sliding_tackle gk_diving  \
# player_name
# Aaron Cresswell       None              78             79        14
# Aaron Ramsdale        None              16             15        82
# Abdoulaye Doucouré    None              80             76        15
# Adam Lallana          None              62             62         6
# Adam Webster          None              77             74        10
#
#                    gk_handling gk_kicking gk_positioning gk_reflexes
# player_name
# Aaron Cresswell              7          9              9          12
# Aaron Ramsdale              77         84             78          84
# Abdoulaye Doucouré          12         12             15          14
# Adam Lallana                15         14              8          11
# Adam Webster                 8         14              7          12
